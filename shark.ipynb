# %%
#!pip install geopandas

# %%
import pandas as pd

# file_path = 'AustralianShark.xlsx'

shark_data = pd.read_csv("AustraliaShark.csv")
shark_data['Latitude'] = shark_data.Latitude.astype('float')
shark_data['Longitude'] = shark_data.Longitude.astype('float')

# %%
import pandas as pd
ss = pd.read_csv('AustraliaShark.csv')
ss
# Out:
#          UIN  Incident.month  Incident.year Victim.injury State  \
# 0        1.0             1.0         1791.0         fatal   NSW
# 1        2.0             3.0         1803.0       injured    WA
# 2        3.0             1.0         1807.0       injured   NSW
# 3        4.0             1.0         1820.0         fatal   TAS
# 4        5.0             1.0         1825.0       injured   NSW
# ...      ...             ...            ...           ...   ...
# 1214  1215.0             4.0         2023.0       injured    WA
# 1215  1216.0             5.0         2023.0         fatal    SA
# 1216  1217.0             5.0         2023.0     uninjured   NSW
# 1217  1218.0             7.0         2023.0       injured    WA
# 1218     NaN             NaN            NaN           NaN   NaN
#
#                               Location      Latitude   Longitude  \
# 0                          near sydney  -33.86666667  151.200000
# ...

# %%
ss
# Out:
#          UIN  Incident.month  Incident.year Victim.injury State  \
# 0        1.0             1.0         1791.0         fatal   NSW
# 1        2.0             3.0         1803.0       injured    WA
# 2        3.0             1.0         1807.0       injured   NSW
# 3        4.0             1.0         1820.0         fatal   TAS
# 4        5.0             1.0         1825.0       injured   NSW
# ...      ...             ...            ...           ...   ...
# 1214  1215.0             4.0         2023.0       injured    WA
# 1215  1216.0             5.0         2023.0         fatal    SA
# 1216  1217.0             5.0         2023.0     uninjured   NSW
# 1217  1218.0             7.0         2023.0       injured    WA
# 1218     NaN             NaN            NaN           NaN   NaN
#
#                               Location      Latitude   Longitude  \
# 0                          near sydney  -33.86666667  151.200000
# ...

# %%
import os
import cartopy
import cartopy.crs as ccrs
cartopy.config['data_dir'] = os.getenv('CARTOPY_DIR', cartopy.config.get('data_dir'))
# Out:
# libpodofo.so.0.9.8: cannot open shared object file: No such file or directory
# libpodofo.so.0.9.8: cannot open shared object file: No such file or directory
# libpodofo.so.0.9.8: cannot open shared object file: No such file or directory
# libpodofo.so.0.9.8: cannot open shared object file: No such file or directory

# %%
ccrs.PlateCarree()
# Out:
# <Projected CRS: +proj=eqc +ellps=WGS84 +a=6378137.0 +lon_0=0.0 +to ...>
# Name: unknown
# Axis Info [cartesian]:
# - E[east]: Easting (unknown)
# - N[north]: Northing (unknown)
# - h[up]: Ellipsoidal height (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unknown
# - method: Equidistant Cylindrical
# Datum: Unknown based on WGS 84 ellipsoid
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.axes(projection=ccrs.PlateCarree())
# Out:
# <GeoAxes: >

# %%
central_lon, central_lat = -10, 45
extent = [-40, 20, 30, 60]
ax = plt.axes(projection=ccrs.Orthographic(central_lon, central_lat))
ax.set_extent(extent)
ax.gridlines()
ax.coastlines(resolution='50m')

# %%
import cartopy.feature as cfeature
import numpy as np

central_lat = -23.
central_lon = 132.
extent = [112, 154, -44, -9]
central_lon = np.mean(extent[:2])
central_lat = np.mean(extent[2:])

albo = ccrs.AlbersEqualArea(central_latitude=0,
 false_easting=0, 
 false_northing=0, 
 central_longitude=132, 
 standard_parallels=(-18, -36) )

plt.figure(figsize=(12, 10))
ax = plt.axes(projection=albo)
ax.set_extent(extent)

ax.add_feature(cartopy.feature.OCEAN)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.RIVERS)
ax.gridlines()

# %%
import cartopy.feature as cfeature
import numpy as np

central_lat = -23.
central_lon = 132.
extent = [112, 154, -44, -9]
central_lon = np.mean(extent[:2])
central_lat = np.mean(extent[2:])

albo = ccrs.AlbersEqualArea(central_latitude=0,
 false_easting=0, 
 false_northing=0, 
 central_longitude=132, 
 standard_parallels=(-18, -36) )

plt.figure(figsize=(12, 10))
ax = plt.axes(projection=albo)
ax.set_extent(extent)

ax.add_feature(cartopy.feature.OCEAN)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.RIVERS)
ax.gridlines()

sydney = dict(lon=151.2093, lat=-33.8688)
perth = dict(lon=115.8613, lat=-31.9523)

lons = [sydney['lon'], perth['lon']]
lats = [sydney['lat'], perth['lat']]

# set a margin around the data
#ax.set_xmargin(0.05)
#ax.set_ymargin(0.10)

ax.coastlines(resolution='50m', color='black', linewidth=1)

ax.plot(151.200000, -33.86666667, 'bo', markersize=5, transform=ccrs.Geodetic())
ax.plot(113.883333, -25.83333333, 'bo', markersize=5, transform=ccrs.Geodetic())
ax.text(-34, 152, 'Australia', transform=ccrs.Geodetic())

ax.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
shark2= shark_data[['Latitude','Longitude']].dropna()
whitesharks = shark_data[shark_data['Shark.common.name']=='white shark']
tigersharks = shark_data[shark_data['Shark.common.name']=='tiger shark']
blacktips = shark_data[shark_data['Shark.common.name']=='black tip reef']
bronze = shark_data[shark_data['Shark.common.name']=='bronze whaler shark']
bull = shark_data[shark_data['Shark.common.name']=='bull shark']
dusky = shark_data[shark_data['Shark.common.name']=='dusky shark']
greyn = shark_data[shark_data['Shark.common.name']=='grey nurse shark']
grey = shark_data[shark_data['Shark.common.name']=='grey reef shark']
wobbe = shark_data[shark_data['Shark.common.name']=='wobbegong']
whitetip = shark_data[shark_data['Shark.common.name']=='whitetip reef shark']
whaler = shark_data[shark_data['Shark.common.name']=='whaler shark']
lemon = shark_data[shark_data['Shark.common.name']=='lemon shark']
hammer = shark_data[shark_data['Shark.common.name']=='hammerhead shark']


recentshark = shark_data[shark_data['Incident.year']>1923]

# %%
# shark2['Longitude']

# %%
#!pip install matplotlib

# %%
import matplotlib.ticker as mticker

central_lat = -23.
central_lon = 132.
extent = [112, 154, -44, -9]
central_lon = np.mean(extent[:2])
central_lat = np.mean(extent[2:])

albo = ccrs.AlbersEqualArea(central_latitude=0,
 false_easting=0, 
 false_northing=0, 
 central_longitude=132, 
 standard_parallels=(-18, -36) )

plt.figure(figsize=(12, 10))
ax = plt.axes(projection=albo)
ax.set_extent(extent)

ax.add_feature(cartopy.feature.OCEAN)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.RIVERS)
ax.gridlines()

# Create a scatter plot using ax.plot
# fig, ax = plt.subplots()
#ax.plot(shark2['Longitude'], shark2['Latitude'], 'ro', transform=ccrs.Geodetic())  # 'ro' for red circles
#ax.plot(recentshark['Longitude'], recentshark['Latitude'], 'wo', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(whitesharks['Longitude'], whitesharks['Latitude'], 'o',color='black', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(tigersharks['Longitude'], tigersharks['Latitude'], 'ro', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(blacktips['Longitude'], blacktips['Latitude'], 'o', color='white', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(bronze['Longitude'], bronze['Latitude'], 'o',color='sandybrown', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(bull['Longitude'], bull['Latitude'], 'o',color='olive', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(dusky['Longitude'], dusky['Latitude'], 'o',color='darkgray', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(greyn['Longitude'], greyn['Latitude'], 'o', color='purple', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(grey['Longitude'], grey['Latitude'], 'o', color='palegreen', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(wobbe['Longitude'], wobbe['Latitude'], 'o', color='blue', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(whitetip['Longitude'], whitetip['Latitude'], 'o',color='dodgerblue', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(whaler['Longitude'], whaler['Latitude'], 'o', color='pink', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(lemon['Longitude'], lemon['Latitude'], 'o',color='khaki', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(hammer['Longitude'], hammer['Latitude'], 'o',color='darkred', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles

# Add legend
plt.legend(["White Shark", "Tiger Shark", "Black Tip", "Bronze Whaler", "bull shark", "Dusky Skark", "Grey Nurse Shark", "Grey Reef Shark", "Wobbegong", "Whitetip Reef Shark", "Whaler Shark", "Lemon Shark", "Hammerhead Shark"], loc ="lower left", fontsize='small')
plt.title("Australian Shark Attack Distrubtion by Species (1923-2023)",fontsize=22,color="black"),

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=2, color='gray', alpha=0.5, linestyle='--')
gl.xlines = False
gl.xlocator = mticker.FixedLocator([-180, -45, 0, 45, 180])
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.xlabel_style = {'size': 15, 'color': 'gray'}
gl.xlabel_style = {'color': 'red', 'weight': 'bold'}

# shark_data['Latitude']
# shark_data['Longitude']
# Customize plot settings (optional)
# ax.plot('Longitude')
# ax.plot('Latitude')

# %%
import matplotlib.ticker as mticker

central_lat = -23.
central_lon = 132.
extent = [140, 160, -10, -30]
central_lon = np.mean(extent[:2])
central_lat = np.mean(extent[2:])

albo = ccrs.AlbersEqualArea(central_latitude=0,
 false_easting=0, 
 false_northing=0, 
 central_longitude=132, 
 standard_parallels=(-18, -36) )

plt.figure(figsize=(12, 10))
ax = plt.axes(projection=albo)
ax.set_extent(extent)

ax.add_feature(cartopy.feature.OCEAN)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.RIVERS)
ax.gridlines()

# Create a scatter plot using ax.plot
# fig, ax = plt.subplots()
#ax.plot(shark2['Longitude'], shark2['Latitude'], 'ro', transform=ccrs.Geodetic())  # 'ro' for red circles
#ax.plot(recentshark['Longitude'], recentshark['Latitude'], 'wo', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(whitesharks['Longitude'], whitesharks['Latitude'], 'o',color='black', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(tigersharks['Longitude'], tigersharks['Latitude'], 'ro', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(blacktips['Longitude'], blacktips['Latitude'], 'o', color='white', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(bronze['Longitude'], bronze['Latitude'], 'o',color='sandybrown', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(bull['Longitude'], bull['Latitude'], 'o',color='olive', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(dusky['Longitude'], dusky['Latitude'], 'o',color='darkgray', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(greyn['Longitude'], greyn['Latitude'], 'o', color='purple', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(grey['Longitude'], grey['Latitude'], 'o', color='palegreen', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(wobbe['Longitude'], wobbe['Latitude'], 'o', color='blue', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(whitetip['Longitude'], whitetip['Latitude'], 'o',color='dodgerblue', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(whaler['Longitude'], whaler['Latitude'], 'o', color='pink', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(lemon['Longitude'], lemon['Latitude'], 'o',color='khaki', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles
ax.plot(hammer['Longitude'], hammer['Latitude'], 'o',color='darkred', markersize=3.5, transform=ccrs.Geodetic())  # 'ro' for red circles

# Add legend
plt.legend(["White Shark", "Tiger Shark", "Black Tip", "Bronze Whaler", "bull shark", "Dusky Skark", "Grey Nurse Shark", "Grey Reef Shark", "Wobbegong", "Whitetip Reef Shark", "Whaler Shark", "Lemon Shark", "Hammerhead Shark"], loc ="lower right", fontsize='small')
plt.title("QLD Shark Attack Distrubtion by Species (1923-2023)",fontsize=22,color="black"),

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=2, color='gray', alpha=0.5, linestyle='--')
gl.xlines = False
gl.xlocator = mticker.FixedLocator([-180, -45, 0, 45, 180])
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.xlabel_style = {'size': 15, 'color': 'gray'}
gl.xlabel_style = {'color': 'red', 'weight': 'bold'}

# shark_data['Latitude']
# shark_data['Longitude']
# Customize plot settings (optional)
# ax.plot('Longitude')
# ax.plot('Latitude')

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import cartopy.crs as ccrs

from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER


ax = plt.axes(projection=ccrs.Mercator())
ax.coastlines()

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=2, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_left = False
gl.xlines = False
gl.xlocator = mticker.FixedLocator([-180, -45, 0, 45, 180])
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.xlabel_style = {'size': 15, 'color': 'gray'}
gl.xlabel_style = {'color': 'red', 'weight': 'bold'}

plt.show()
# Out:
# /usr/lib/python3.11/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /usr/lib/python3.11/site-packages/cartopy/mpl/gridliner.py:475: UserWarning: The .ylabels_left attribute is deprecated. Please use .left_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_left attribute is deprecated. Please '

# %%
shark_data.dtypes
# Out:
# UIN                            float64
# Incident.month                 float64
# Incident.year                  float64
# Victim.injury                   object
# State                           object
# Location                        object
# Latitude                       float64
# Longitude                      float64
# Site.category                   object
# Site.category.comment           object
# Shark.common.name               object
# Shark.scientific.name           object
# Shark.identification.method     object
# Shark.identification.source     object
# Shark.length.m                 float64
# Basis.for.length                object
# Provoked/unprovoked             object
# Provocative.act                 object
# No.sharks                      float64
# Victim.activity                 object
# Fish.speared?                   object
# Commercial.dive.activity        object
# Object.of.bite                  object
# Present.at.time.of.bite         object
# ...

# %% [markdown]
# import matplotlib.pyplot as plt
# import matplotlib.ticker as mticker
# import cartopy.crs as ccrs
#
# from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
#
#
# ax = plt.axes(projection=ccrs.Mercator())
# ax.coastlines()
#
# gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
#                   linewidth=2, color='gray', alpha=0.5, linestyle='--')
# gl.xlabels_top = False
# gl.ylabels_left = False
# gl.xlines = False
# gl.xlocator = mticker.FixedLocator([-180, -45, 0, 45, 180])
# gl.xformatter = LONGITUDE_FORMATTER
# gl.yformatter = LATITUDE_FORMATTER
# gl.xlabel_style = {'size': 15, 'color': 'gray'}
# gl.xlabel_style = {'color': 'red', 'weight': 'bold'}
#
# plt.show()

# %%
shark2.Longitude.min()
# Out:
# 96.81666667

# %%
plt.legend(["White Shark", "Tiger Shark"], loc ="lower right")

# %%
# ... (your existing code)

# Create a scatter plot using ax.plot for each shark type
ax.plot(recentshark['Longitude'], recentshark['Latitude'], 'bo', markersize=3.5, label='Recent Shark', transform=ccrs.Geodetic())
ax.plot(whitesharks['Longitude'], whitesharks['Latitude'], 'wo', markersize=3.5, label='White Shark', transform=ccrs.Geodetic())
ax.plot(tigersharks['Longitude'], tigersharks['Latitude'], 'ro', markersize=3.5, label='Tiger Shark', transform=ccrs.Geodetic())
# ... (repeat for other shark types)

# Add legend
ax.legend(loc='upper right', fontsize='medium')

# ... (continue with your code)

# %%
urls = 'https://thredds.ereefs.aims.gov.au/thredds/dodsC/ereefs/GBR4_H2p0_B3p1_Cq3b_Dhnd/monthly-monthly/EREEFS_AIMS-CSIRO_GBR4_H2p0_B3p1_Cq3b_Dhnd_bgc_monthly-monthly'
months = [11, 12, 1]
# years = ['2010']
files = [f'{urls}-{year}-{month:02d}.nc' for year in range (2010, 2020) for month in months]

# %%
urls = 'https://thredds.ereefs.aims.gov.au/thredds/dodsC/ereefs/GBR4_H2p0_B3p1_Cq3b_Dhnd/monthly-monthly/EREEFS_AIMS-CSIRO_GBR4_H2p0_B3p1_Cq3b_Dhnd_bgc_monthly-monthly'
months = [11, 12, 1]
# years = ['2010']
files2 = [f'{urls}-{year}-{month:02d}.nc' for year in range (2015, 2016, 2020) for month in months]

# %%
files2
# Out:
# ['https://thredds.ereefs.aims.gov.au/thredds/dodsC/ereefs/GBR4_H2p0_B3p1_Cq3b_Dhnd/monthly-monthly/EREEFS_AIMS-CSIRO_GBR4_H2p0_B3p1_Cq3b_Dhnd_bgc_monthly-monthly-2015-11.nc',
#  'https://thredds.ereefs.aims.gov.au/thredds/dodsC/ereefs/GBR4_H2p0_B3p1_Cq3b_Dhnd/monthly-monthly/EREEFS_AIMS-CSIRO_GBR4_H2p0_B3p1_Cq3b_Dhnd_bgc_monthly-monthly-2015-12.nc',
#  'https://thredds.ereefs.aims.gov.au/thredds/dodsC/ereefs/GBR4_H2p0_B3p1_Cq3b_Dhnd/monthly-monthly/EREEFS_AIMS-CSIRO_GBR4_H2p0_B3p1_Cq3b_Dhnd_bgc_monthly-monthly-2015-01.nc']

# %%
files
# Out:
# ['https://thredds.ereefs.aims.gov.au/thredds/dodsC/ereefs/GBR4_H2p0_B3p1_Cq3b_Dhnd/monthly-monthly/EREEFS_AIMS-CSIRO_GBR4_H2p0_B3p1_Cq3b_Dhnd_bgc_monthly-monthly-2010-11.nc',
#  'https://thredds.ereefs.aims.gov.au/thredds/dodsC/ereefs/GBR4_H2p0_B3p1_Cq3b_Dhnd/monthly-monthly/EREEFS_AIMS-CSIRO_GBR4_H2p0_B3p1_Cq3b_Dhnd_bgc_monthly-monthly-2010-12.nc',
#  'https://thredds.ereefs.aims.gov.au/thredds/dodsC/ereefs/GBR4_H2p0_B3p1_Cq3b_Dhnd/monthly-monthly/EREEFS_AIMS-CSIRO_GBR4_H2p0_B3p1_Cq3b_Dhnd_bgc_monthly-monthly-2010-01.nc',
#  'https://thredds.ereefs.aims.gov.au/thredds/dodsC/ereefs/GBR4_H2p0_B3p1_Cq3b_Dhnd/monthly-monthly/EREEFS_AIMS-CSIRO_GBR4_H2p0_B3p1_Cq3b_Dhnd_bgc_monthly-monthly-2011-11.nc',
#  'https://thredds.ereefs.aims.gov.au/thredds/dodsC/ereefs/GBR4_H2p0_B3p1_Cq3b_Dhnd/monthly-monthly/EREEFS_AIMS-CSIRO_GBR4_H2p0_B3p1_Cq3b_Dhnd_bgc_monthly-monthly-2011-12.nc',
# ...

# %%
files1 = files [3:-3]
files1.append('https://thredds.ereefs.aims.gov.au/thredds/dodsC/ereefs/GBR4_H2p0_B3p1_Cq3b_Dhnd/monthly-monthly/EREEFS_AIMS-CSIRO_GBR4_H2p0_B3p1_Cq3b_Dhnd_bgc_monthly-monthly-2019-01.nc')
files1
# Out:
# ['https://thredds.ereefs.aims.gov.au/thredds/dodsC/ereefs/GBR4_H2p0_B3p1_Cq3b_Dhnd/monthly-monthly/EREEFS_AIMS-CSIRO_GBR4_H2p0_B3p1_Cq3b_Dhnd_bgc_monthly-monthly-2011-11.nc',
#  'https://thredds.ereefs.aims.gov.au/thredds/dodsC/ereefs/GBR4_H2p0_B3p1_Cq3b_Dhnd/monthly-monthly/EREEFS_AIMS-CSIRO_GBR4_H2p0_B3p1_Cq3b_Dhnd_bgc_monthly-monthly-2011-12.nc',
#  'https://thredds.ereefs.aims.gov.au/thredds/dodsC/ereefs/GBR4_H2p0_B3p1_Cq3b_Dhnd/monthly-monthly/EREEFS_AIMS-CSIRO_GBR4_H2p0_B3p1_Cq3b_Dhnd_bgc_monthly-monthly-2011-01.nc',
#  'https://thredds.ereefs.aims.gov.au/thredds/dodsC/ereefs/GBR4_H2p0_B3p1_Cq3b_Dhnd/monthly-monthly/EREEFS_AIMS-CSIRO_GBR4_H2p0_B3p1_Cq3b_Dhnd_bgc_monthly-monthly-2012-11.nc',
#  'https://thredds.ereefs.aims.gov.au/thredds/dodsC/ereefs/GBR4_H2p0_B3p1_Cq3b_Dhnd/monthly-monthly/EREEFS_AIMS-CSIRO_GBR4_H2p0_B3p1_Cq3b_Dhnd_bgc_monthly-monthly-2012-12.nc',
# ...

# %%
import xarray as xr

# %%
envVar = xr.open_mfdataset(files1, parallel = True)
envVar

# %%
print ('depth', envVar.zc.values[14:17])
# Out:
# depth [-3.  -1.5 -0.5]

# %%
conVars = ['temp', 'salt', 'Chl_a_sum']

# %%
top = envVar.isel(k = slice (14,17))[conVars].mean(dim = 'k')

# %%
meandata = top.mean(dim = 'time')[conVars]

# %%
meandata
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 723, longitude: 491)
# Coordinates:
#   * latitude   (latitude) float64 -28.7 -28.67 -28.64 ... -7.096 -7.066 -7.036
#   * longitude  (longitude) float64 142.2 142.2 142.2 142.3 ... 156.8 156.8 156.9
# Data variables:
#     temp       (latitude, longitude) float32 dask.array<chunksize=(723, 491), meta=np.ndarray>
#     salt       (latitude, longitude) float32 dask.array<chunksize=(723, 491), meta=np.ndarray>
#     Chl_a_sum  (latitude, longitude) float32 dask.array<chunksize=(723, 491), meta=np.ndarray>

# %%
meandata.temp.plot()

# %%
meandata.salt.plot()

# %%
meandata.Chl_a_sum.plot()

# %%
ss
# Out:
#          UIN  Incident.month  Incident.year Victim.injury State  \
# 0        1.0             1.0         1791.0         fatal   NSW
# 1        2.0             3.0         1803.0       injured    WA
# 2        3.0             1.0         1807.0       injured   NSW
# 3        4.0             1.0         1820.0         fatal   TAS
# 4        5.0             1.0         1825.0       injured   NSW
# ...      ...             ...            ...           ...   ...
# 1214  1215.0             4.0         2023.0       injured    WA
# 1215  1216.0             5.0         2023.0         fatal    SA
# 1216  1217.0             5.0         2023.0     uninjured   NSW
# 1217  1218.0             7.0         2023.0       injured    WA
# 1218     NaN             NaN            NaN           NaN   NaN
#
#                               Location   Latitude   Longitude  \
# 0                          near sydney -33.866667  151.200000
# 1            hamelin bay, faure island -25.833333  113.883333
# ...

# %%
lon_min, lon_max = float(meandata.longitude.min()), float(meandata.longitude.max())
lat_min, lat_max = float(meandata.latitude.min()), float(meandata.latitude.max())

# %%
ss['Longitude'] = pd.to_numeric(ss['Longitude'], errors = 'coerce')
ss['Latitude'] = pd.to_numeric(ss['Latitude'], errors = 'coerce')

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import cartopy.crs as ccrs

# %%
ss_within_range = ss[(ss['Longitude'] >= lon_min) & (ss['Longitude'] <= lon_max) & (ss['Latitude'] >= lat_min) & (ss['Latitude'] <= lat_max)]
ss_within_range
# Out:
#          UIN  Incident.month  Incident.year Victim.injury State  \
# 9       10.0             8.0         1836.0         fatal   QLD
# 10      11.0             8.0         1836.0         fatal   QLD
# 15      16.0             3.0         1847.0       injured   QLD
# 16      17.0            11.0         1847.0       injured   QLD
# 20      21.0             1.0         1850.0         fatal   QLD
# ...      ...             ...            ...           ...   ...
# 1156  1157.0            10.0         2020.0       injured   QLD
# 1159  1160.0            11.0         2020.0     uninjured   QLD
# 1182  1183.0            10.0         2021.0       injured   QLD
# 1187  1188.0            12.0         2021.0       injured   QLD
# 1193  1194.0             2.0         2022.0       injured   QLD
#
#                                             Location   Latitude   Longitude  \
# 9                                      fraser island -25.483333  152.983333
# ...

# %%
plt.figure(figsize=(10,6))
plt.scatter(ss_within_range['Longitude'], ss_within_range['Latitude'])
plt.title('Scatter plot of Longitude and Latitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
sharklats = ss_within_range['Latitude'].values
sharklons = ss_within_range['Longitude'].values

# %%
meandata.load()

# %%
chlPts = []
tempPts = []
saltPts = []
for k in range(len(sharklons)):
    tmp = meandata.where(latitude=sharklats[k],longitude=sharklons[k],method='nearest')
    chlPts.append(tmp.Chl_a_sum.values+0.)
    tempPts.append(tmp.temp.values+0.)
    saltPts.append(tmp.salt.values+0.)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 saltPts = []
#       4 for k in range(len(sharklons)):
# ----> 5     tmp = meandata.where(latitude=sharklats[k],longitude=sharklons[k],method='nearest')
#       6     chlPts.append(tmp.Chl_a_sum.values+0.)
#       7     tempPts.append(tmp.temp.values+0.)
#
# TypeError: DataWithCoords.where() got an unexpected keyword argument 'latitude'

# %%
ss_within_range['salt'] = saltPts
ss_within_range['temp'] = tempPts
ss_within_range['Chl_a_sum'] = chlPts
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ss_within_range['salt'] = saltPts
#       2 ss_within_range['temp'] = tempPts
#       3 ss_within_range['Chl_a_sum'] = chlPts
#
# File /usr/lib/python3.11/site-packages/pandas/core/frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File /usr/lib/python3.11/site-packages/pandas/core/frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
#    4176     if (
#    4177         key in self.columns
# ...

# %%
ss_within_range.to_csv('myshark_hydrovar.csv',index=False)

# %%
ss_within_range.rename(columns={'Latitude': 'latitude'}, inplace=True)
ss_within_range.rename(columns={'Longitude': 'longitude'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ss_within_range.rename(columns={'Latitude': 'latitude'}, inplace=True)
#       2 ss_within_range.rename(columns={'Longitude': 'longitude'}, inplace=True)
#
# NameError: name 'ss_within_range' is not defined

# %%
ss_within_range
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ss_within_range
#
# NameError: name 'ss_within_range' is not defined

# %%
meandata_xr = meandata.to_dataframe().reset_index()
meandata_xr
# Out:
#          latitude   longitude  temp  salt  Chl_a_sum
# 0      -28.696022  142.168788   NaN   NaN        NaN
# 1      -28.696022  142.198788   NaN   NaN        NaN
# 2      -28.696022  142.228788   NaN   NaN        NaN
# 3      -28.696022  142.258788   NaN   NaN        NaN
# 4      -28.696022  142.288788   NaN   NaN        NaN
# ...           ...         ...   ...   ...        ...
# 354988  -7.036022  156.748788   NaN   NaN        NaN
# 354989  -7.036022  156.778788   NaN   NaN        NaN
# 354990  -7.036022  156.808788   NaN   NaN        NaN
# 354991  -7.036022  156.838788   NaN   NaN        NaN
# 354992  -7.036022  156.868788   NaN   NaN        NaN
#
# [354993 rows x 5 columns]

# %%
meandata_xr
# Out:
#          latitude   longitude  temp  salt  Chl_a_sum
# 0      -28.696022  142.168788   NaN   NaN        NaN
# 1      -28.696022  142.198788   NaN   NaN        NaN
# 2      -28.696022  142.228788   NaN   NaN        NaN
# 3      -28.696022  142.258788   NaN   NaN        NaN
# 4      -28.696022  142.288788   NaN   NaN        NaN
# ...           ...         ...   ...   ...        ...
# 354988  -7.036022  156.748788   NaN   NaN        NaN
# 354989  -7.036022  156.778788   NaN   NaN        NaN
# 354990  -7.036022  156.808788   NaN   NaN        NaN
# 354991  -7.036022  156.838788   NaN   NaN        NaN
# 354992  -7.036022  156.868788   NaN   NaN        NaN
#
# [354993 rows x 5 columns]

# %%
# Merge the DataFrames based on common columns
merged_df = pd.merge(meandata_xr, ss_within_range, on=['longitude', 'latitude'], how='inner')

# Convert the merged DataFrame back to xarray dataset
merged_xarray_data = merged_df.set_index(['longitude', 'latitude']).to_xarray()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Merge the DataFrames based on common columns
# ----> 2 merged_df = pd.merge(meandata_xr, ss_within_range, on=['longitude', 'latitude'], how='inner')
#       4 # Convert the merged DataFrame back to xarray dataset
#       5 merged_xarray_data = merged_df.set_index(['longitude', 'latitude']).to_xarray()
#
# NameError: name 'pd' is not defined
